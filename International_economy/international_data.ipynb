# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("PovStatsEdit.csv")

# %%
df
# Out:
#              Country Name Country Code  \
# 0     East Asia & Pacific          EAS
# 1     East Asia & Pacific          EAS
# 2     East Asia & Pacific          EAS
# 3     East Asia & Pacific          EAS
# 4     East Asia & Pacific          EAS
# ...                   ...          ...
# 8135             Zimbabwe          ZWE
# 8136             Zimbabwe          ZWE
# 8137             Zimbabwe          ZWE
# 8138             Zimbabwe          ZWE
# 8139             Zimbabwe          ZWE
#
#                                          Indicator Name  Indicator Code  1974  \
# 0     Annualized growth in per capita real survey me...  SI.SPR.PC40.ZG   NaN
# 1     Annualized growth in per capita real survey me...  SI.SPR.PT10.ZG   NaN
# 2     Annualized growth in per capita real survey me...  SI.SPR.PT60.ZG   NaN
# 3     Annualized growth in per capita real survey me...  SI.SPR.PCAP.ZG   NaN
# 4                      GINI index (World Bank estimate)     SI.POV.GINI   NaN
# ...

# %%
nba_nations = ['Poland', 'Canada', 'United Kingdom', 'China', 'Germany',
       'Morocco', 'Netherlands', 'Romania', 'Denmark', 'Puerto Rico',
       'Bahamas', 'Panama', 'Iceland', 'France', 'Spain', 'Nigeria',
       'Jamaica', 'South Sudan', 'Bulgaria', 'Haiti', 'Brazil',
       'Dominican Republic', 'Lebanon', 'Norway', 'Serbia', 'Lithuania',
       'Montenegro', 'Croatia', 'Russia', 'Egypt', 'Trinidad and Tobago',
       'Australia', 'Democratic Republic of the Congo', 'Latvia', 'Cuba',
       'Slovakia', 'U.S. Virgin Islands', 'Bosnia and Herzegovina',
       'Italy', 'Czech Republic', 'Mexico', 'Estonia', 'South Africa',
       'Ukraine', 'Saint Vincent and the Grenadines', 'Slovenia',
       'New Zealand', 'Senegal', 'Sweden', 'Guyana', 'Dominica',
       'Finland', 'Mali', 'Argentina', 'Turkey', 'Cameroon', 'Greece',
       'Luxembourg', 'Belgium', 'Venezuela', 'Ireland', 'Guadeloupe',
       'Republic of Korea', 'Japan', 'Uruguay', 'Martinique',
       'Switzerland', 'Gabon', 'Taiwan', 'Islamic Republic of Iran',
       'Israel', 'Republic of the Congo', 'United Republic of Tanzania',
       'French Guiana', 'FYR Macedonia', 'Tunisia', 'Cape Verde',
       'Austria','United States']

# %%
df_edit = df[ df['Country Name'].isin(nba_nations)]

# %%
len(df_edit)
# Out:
# 2508

# %%
len(df_edit['Country Name'].unique())
# Out:
# 57

# %%
len(nba_nations)
# Out:
# 79

# %%
excluded_nba_nations = [ x for x in nba_nations if x not in df_edit['Country Name'].unique()]

# %%
len(excluded_nba_nations)
# Out:
# 22

# %%
excluded_nba_nations
# Out:
# ['Bahamas',
#  'Cape Verde',
#  'Cuba',
#  'Democratic Republic of the Congo',
#  'Dominica',
#  'Egypt',
#  'FYR Macedonia',
#  'French Guiana',
#  'Guadeloupe',
#  'Islamic Republic of Iran',
#  'Martinique',
#  'New Zealand',
#  'Puerto Rico',
#  'Republic of Korea',
#  'Republic of the Congo',
#  'Russia',
#  'Saint Vincent and the Grenadines',
#  'Slovakia',
#  'Taiwan',
#  'U.S. Virgin Islands',
#  'United Republic of Tanzania',
#  'Venezuela']

# %%
map = {'Cape Verde':'Cabo Verde',
 'Democratic Republic of the Congo':'Congo, Dem. Rep.',
 'Egypt':'Egypt, Arab Rep.',
 'FYR Macedonia':'North Macedonia',
 'Islamic Republic of Iran':'Iran, Islamic Rep.',
 'Republic of Korea':'Korea, Rep.',
 'Republic of the Congo':'Congo, Rep.',
 'Russia':'Russian Federation',
 'United Republic of Tanzania':'Tanzania',
 'Venezuela':'Venezuela, RB'}

# %%
map
# Out:
# {'Cape Verde': 'Cabo Verde',
#  'Democratic Republic of the Congo': 'Congo, Dem. Rep.',
#  'Egypt': 'Egypt, Arab Rep.',
#  'FYR Macedonia': 'North Macedonia',
#  'Islamic Republic of Iran': 'Iran, Islamic Rep.',
#  'Republic of Korea': 'Korea, Rep.',
#  'Republic of the Congo': 'Congo, Rep.',
#  'Russia': 'Russian Federation',
#  'United Republic of Tanzania': 'Tanzania',
#  'Venezuela': 'Venezuela, RB'}

# %%
newmap = {}
for pair in map:
    newmap[map[pair]] = pair

# %%
newmap
# Out:
# {'Cabo Verde': 'Cape Verde',
#  'Congo, Dem. Rep.': 'Democratic Republic of the Congo',
#  'Egypt, Arab Rep.': 'Egypt',
#  'North Macedonia': 'FYR Macedonia',
#  'Iran, Islamic Rep.': 'Islamic Republic of Iran',
#  'Korea, Rep.': 'Republic of Korea',
#  'Congo, Rep.': 'Republic of the Congo',
#  'Russian Federation': 'Russia',
#  'Tanzania': 'United Republic of Tanzania',
#  'Venezuela, RB': 'Venezuela'}

# %%
'Venezuela, RB' in newmap
# Out:
# True

# %%
df_excluded = df[ df['Country Name'].isin(newmap) ]

# %%
df_excluded
# Out:
#        Country Name Country Code  \
# 1672     Cabo Verde          CPV
# 1673     Cabo Verde          CPV
# 1674     Cabo Verde          CPV
# 1675     Cabo Verde          CPV
# 1676     Cabo Verde          CPV
# ...             ...          ...
# 7915  Venezuela, RB          VEN
# 7916  Venezuela, RB          VEN
# 7917  Venezuela, RB          VEN
# 7918  Venezuela, RB          VEN
# 7919  Venezuela, RB          VEN
#
#                                          Indicator Name  Indicator Code  1974  \
# 1672  Annualized growth in per capita real survey me...  SI.SPR.PC40.ZG   NaN
# 1673  Annualized growth in per capita real survey me...  SI.SPR.PT10.ZG   NaN
# 1674  Annualized growth in per capita real survey me...  SI.SPR.PT60.ZG   NaN
# 1675  Annualized growth in per capita real survey me...  SI.SPR.PCAP.ZG   NaN
# 1676                   GINI index (World Bank estimate)     SI.POV.GINI   NaN
# ...                                                 ...             ...   ...
# ...

# %%
df_excluded.loc[7919,'Country Name']
# Out:
# 'Venezuela, RB'

# %%
for( index, row) in df_excluded.iterrows():
    df_excluded.loc[index,'Country Name'] = newmap[row['Country Name']]

# %%
df_excluded
# Out:
#      Country Name Country Code  \
# 1672   Cape Verde          CPV
# 1673   Cape Verde          CPV
# 1674   Cape Verde          CPV
# 1675   Cape Verde          CPV
# 1676   Cape Verde          CPV
# ...           ...          ...
# 7915    Venezuela          VEN
# 7916    Venezuela          VEN
# 7917    Venezuela          VEN
# 7918    Venezuela          VEN
# 7919    Venezuela          VEN
#
#                                          Indicator Name  Indicator Code  1974  \
# 1672  Annualized growth in per capita real survey me...  SI.SPR.PC40.ZG   NaN
# 1673  Annualized growth in per capita real survey me...  SI.SPR.PT10.ZG   NaN
# 1674  Annualized growth in per capita real survey me...  SI.SPR.PT60.ZG   NaN
# 1675  Annualized growth in per capita real survey me...  SI.SPR.PCAP.ZG   NaN
# 1676                   GINI index (World Bank estimate)     SI.POV.GINI   NaN
# ...                                                 ...             ...   ...
# ...

# %%
new_df = df_edit + df_excluded

# %%
len(df_edit)
# Out:
# 2508

# %%
len(df_excluded)
# Out:
# 440

# %%
len(new_df)
# Out:
# 2948

# %%
df = df_edit.append(df_excluded)

# %%
df
# Out:
#      Country Name Country Code  \
# 880     Argentina          ARG
# 881     Argentina          ARG
# 882     Argentina          ARG
# 883     Argentina          ARG
# 884     Argentina          ARG
# ...           ...          ...
# 7915    Venezuela          VEN
# 7916    Venezuela          VEN
# 7917    Venezuela          VEN
# 7918    Venezuela          VEN
# 7919    Venezuela          VEN
#
#                                          Indicator Name  Indicator Code  1974  \
# 880   Annualized growth in per capita real survey me...  SI.SPR.PC40.ZG   NaN
# 881   Annualized growth in per capita real survey me...  SI.SPR.PT10.ZG   NaN
# 882   Annualized growth in per capita real survey me...  SI.SPR.PT60.ZG   NaN
# 883   Annualized growth in per capita real survey me...  SI.SPR.PCAP.ZG   NaN
# 884                    GINI index (World Bank estimate)     SI.POV.GINI   NaN
# ...                                                 ...             ...   ...
# ...

# %%
df_edit = df.dropna(thresh=7)

# %%
len(df)
# Out:
# 2948

# %%
len(df_edit)
# Out:
# 1199

# %%
df_edit
# Out:
#      Country Name Country Code  \
# 884     Argentina          ARG
# 888     Argentina          ARG
# 889     Argentina          ARG
# 890     Argentina          ARG
# 891     Argentina          ARG
# ...           ...          ...
# 7900    Venezuela          VEN
# 7901    Venezuela          VEN
# 7902    Venezuela          VEN
# 7903    Venezuela          VEN
# 7904    Venezuela          VEN
#
#                                          Indicator Name  Indicator Code  1974  \
# 884                    GINI index (World Bank estimate)     SI.POV.GINI   NaN
# 888                     Income share held by fourth 20%  SI.DST.04TH.20   NaN
# 889                    Income share held by highest 10%  SI.DST.10TH.10   NaN
# 890                    Income share held by highest 20%  SI.DST.05TH.20   NaN
# 891                     Income share held by lowest 10%  SI.DST.FRST.10   NaN
# ...                                                 ...             ...   ...
# ...

# %%
df_edit.to_csv("int_poverty_data.csv")
